# %%
train.n.hist()
# Out:
# <AxesSubplot:>

# %%
train.n.hist()
# Out:
# <AxesSubplot:>

# %%
# Out:
#   File "/tmp/ipykernel_4677/1313523144.py", line 1
#     call =
#           ^
# SyntaxError: invalid syntax

# %%
train_input[0]
# Out:
# array([ 0.2682314 ,  0.97617679,  0.09187183,  6.        , 21.        ,
#        15.        , 41.        ])

# %%
# Out:
# /tmp/ipykernel_56765/2984617662.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(train_input, train_label)
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
# Out:
# 1.0

# %%
# Out:
# array([[1160]])
